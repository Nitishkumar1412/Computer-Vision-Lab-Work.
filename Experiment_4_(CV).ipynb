# %% [markdown]
# <a href="https://colab.research.google.com/github/Nitishkumar1412/Computer-Vision-Lab-Work./blob/main/Experiment_4_(CV).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**AIM: Program for opening and closing of the image.**

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

# %%
image = cv2.imread('image.jpeg', 0)

# %%
kernel = np.ones((5, 5), np.uint8)

# %%
opening = cv2.morphologyEx(image, cv2.MORPH_OPEN, kernel)

# %%
closing = cv2.morphologyEx(image, cv2.MORPH_CLOSE, kernel)

# %%
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=L size=736x734>

# %%
cv2_imshow(opening)
# Out:
# <PIL.Image.Image image mode=L size=736x734>

# %%
cv2_imshow(closing)
# Out:
# <PIL.Image.Image image mode=L size=736x734>
